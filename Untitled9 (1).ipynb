# %%
import pandas as pd

# %%
df=pd.read_csv("null.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#dimensionality of dataset
df.shape
# Out:
# (205, 26)

# %%
#discriptive infor about the dataset
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#Name  of features
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#check if there is any duplicated rows in our dataset
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
#Splitting car name from company name
df['CarName']=df['CarName'].apply(lambda x:x.split(' ')[0])

# %%
df.head()
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
#Caplitalizing the car name
df['CarName']=df['CarName'].str.capitalize()
df.head()
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber      carbody  \
# 0       1          3  Alfa-romero      gas        std        two  convertible
# 1       2          3  Alfa-romero      gas        std        two  convertible
# 2       3          1  Alfa-romero      gas        std        two    hatchback
# 3       4          2         Audi      gas        std       four        sedan
# 4       5          2         Audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.title("Car Price Prediction")
sns.distplot(df.price)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.title("Car Speed Spread")
sns.boxplot(y=df.price)

# %%
plt.figure(figsize=(15,8))
corr=sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Here is the Correlation Graph

# %% [markdown]
# highwaympg and citympg are positively correlated with coefficient of 90%

# %% [markdown]
# carlength and curbweigth are positively correlated with coefficient of 87%

# %% [markdown]
# stroke and carheight are negatively correlated with coefficient of about 5%

# %% [markdown]
# citympg and symboling are negatively correlated with coefficient of nearly 3%

# %%
# !pip install dython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.4 MB 11.2 MB/s
# ...
#      |████████████████████████████████| 280 kB 49.7 MB/s
# ...
#      |████████████████████████████████| 965 kB 46.2 MB/s
# ...
#      |████████████████████████████████| 295 kB 81.3 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# ...

# %%
from dython.nominal import associations

# %%
associations(df,figsize=(20,20))
plt.show()

# %% [markdown]
# CarName is highly correlated with price with a coefficient of 90% which indicated that the price is car is highly dependent on brand name

# %% [markdown]
# fueltype is very mildly correlated with price with coefficient of only 11% which inferes that the price of car is not much dependent on fuel category

# %% [markdown]
# Compression ratio is highly in positive relation with fuelsystem with coefficient of 99% which reveals the fact that compression ratio factor of a car is highly dependent on fuelsystem

# %% [markdown]
# Symboling is the feature of a car which is negatively correlated with many other features or related positively with minute percentages.

# %%
#cols=['fueltype','aspiration','doornumber','fuelsystem','enginetype','cylindernumber','enginelocation']
import plotly.express as px
carbody = df['carbody'].value_counts().reset_index()
carbody.columns = ['carbody', 'counts']
fig = px.pie(carbody, names = 'carbody', values = 'counts', color_discrete_sequence = px.colors.sequential.Darkmint_r, width = 650, height = 400, hole = 0.25,title="Carbody Analysis")
#fig.update_traces(textinfo = 'percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
aspiration = df['aspiration'].value_counts().reset_index()
aspiration.columns=['aspiration','Counts']
px.pie(aspiration,names='aspiration',values='Counts',width = 650, height = 400, hole = 0.25,title="Aspiration Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['fueltype'].value_counts().reset_index()
col.columns=['fueltype','Counts']
px.pie(col,names='fueltype',values='Counts',width = 650, height = 400, hole = 0.25,title="Fuletype Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['doornumber'].value_counts().reset_index()
col.columns=['doornumber','Counts']
px.pie(col,names='doornumber',values='Counts',width = 650, height = 400, hole = 0.25,title="Door Number Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['enginelocation'].value_counts().reset_index()
col.columns=['enginelocation','Counts']
px.pie(col,names='enginelocation',values='Counts',width = 650, height = 400, hole = 0.25,title="Engine Location Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['enginetype'].value_counts().reset_index()
col.columns=['enginetype','Counts']
px.pie(col,names='enginetype',values='Counts',width = 650, height = 400, hole = 0.25,title="EngineType Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['drivewheel'].value_counts().reset_index()
col.columns=['drivewheel','Counts']
px.pie(col,names='drivewheel',values='Counts',width = 650, height = 400, hole = 0.25,title="Drive Wheel Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
col = df['fuelsystem'].value_counts().reset_index()
col.columns=['fuelsystem','Counts']
px.pie(col,names='fuelsystem',values='Counts',width = 650, height = 400, hole = 0.25,title="Fuel System Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x='enginetype',y='horsepower',color='fueltype')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ohcv engine of gas type has more horsepower than others

# %% [markdown]
# ohc is the most frequent engine that is found

# %%
px.scatter(df,x='wheelbase',y='horsepower')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Most of the data points lie between the 95 to 100 wheelbase size which inferes that this is the common wheelbase size and 200 is the most probable horsepower

# %%
col = df['CarName'].value_counts().reset_index()
col.columns=['CarName','Counts']
px.pie(col,names='CarName',values='Counts',width = 700, height = 600, hole = 0.5,title="Cars Usage Analysis",color_discrete_sequence=px.colors.sequential.RdBu).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Toyota is the most used car followed by Nissan

# %% [markdown]
# Porsche is least used car

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='wheelbase')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='compressionratio')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='enginesize')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='peakrpm')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='aspiration',style='fueltype')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='price',y='horsepower',hue='aspiration',style='enginetype')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='peakrpm',y='horsepower',hue='aspiration',style='fueltype')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='peakrpm',y='horsepower',hue='enginetype',style='fueltype')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='wheelbase',y='peakrpm',hue='enginetype',style='fueltype')
